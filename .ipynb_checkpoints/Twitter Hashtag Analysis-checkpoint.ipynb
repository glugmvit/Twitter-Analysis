# %%
import tweepy
import csv
import pandas as pd
####input your credentials here
consumer_key = 'Z0bEpYrdrA91bIqFhHIUN78Oz'
consumer_secret = 'g5AudmBzHv1Y9eAjixXtV91TrgtCpX6NExb2QhNTV1fH3QAGcj'
access_token = '957223669738045440-NI42JKqdmyN7HinPszkBQzev4L1It9n'
access_token_secret = 'aGoJRuSkDguVnoSQ6SR87eVPcou5BcgR6gLdnwkS547n8'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)
#####United Airlines
# Open/Create a file to append data
csvFile = open('tweets.csv', 'w')
#Use csv Writer
csvWriter = csv.writer(csvFile)

for tweet in tweepy.Cursor(api.search,q="#unitedAIRLINES",count=100,
                           lang="en",
                           since="2017-04-03").items():
    #print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.user.screen_name, tweet.text.encode('utf-8')])
# Out:
# Status(_api=<tweepy.api.API object at 0x7f57302fb0b8>, _json={'created_at': 'Mon Sep 30 19:41:03 +0000 2019', 'id': 1178756663710498816, 'id_str': '1178756663710498816', 'text': 'Dear @united thanks for the major upgrade!  Polaris class rocks! 😁 #unitedairlines #flyunited #unitedfirst… https://t.co/faxlHquqqX', 'truncated': True, 'entities': {'hashtags': [{'text': 'unitedairlines', 'indices': [67, 82]}, {'text': 'flyunited', 'indices': [83, 93]}, {'text': 'unitedfirst', 'indices': [94, 106]}], 'symbols': [], 'user_mentions': [{'screen_name': 'united', 'name': 'United Airlines', 'id': 260907612, 'id_str': '260907612', 'indices': [5, 12]}], 'urls': [{'url': 'https://t.co/faxlHquqqX', 'expanded_url': 'https://twitter.com/i/web/status/1178756663710498816', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [108, 131]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 39873234, 'id_str': '39873234', 'name': 'JC', 'screen_name': 'WineMasterJeff', 'location': 'US', 'description': 'https://t.co/9hHoB31TeY', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/9hHoB31TeY', 'expanded_url': 'https://www.instagram.com/disneyisforadultstoo', 'display_url': 'instagram.com/disneyisforadu…', 'indices': [0, 23]}]}}, 'protected': False, 'followers_count': 29, 'friends_count': 117, 'listed_count': 0, 'created_at': 'Wed May 13 23:50:56 +0000 2009', 'favourites_count': 757, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 6173, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/862392173731471360/McwzqlA0_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/862392173731471360/McwzqlA0_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/39873234/1449055735', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 9, 30, 19, 41, 3), id=1178756663710498816, id_str='1178756663710498816', text='Dear @united thanks for the major upgrade!  Polaris class rocks! 😁 #unitedairlines #flyunited #unitedfirst… https://t.co/faxlHquqqX', truncated=True, entities={'hashtags': [{'text': 'unitedairlines', 'indices': [67, 82]}, {'text': 'flyunited', 'indices': [83, 93]}, {'text': 'unitedfirst', 'indices': [94, 106]}], 'symbols': [], 'user_mentions': [{'screen_name': 'united', 'name': 'United Airlines', 'id': 260907612, 'id_str': '260907612', 'indices': [5, 12]}], 'urls': [{'url': 'https://t.co/faxlHquqqX', 'expanded_url': 'https://twitter.com/i/web/status/1178756663710498816', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [108, 131]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='IFTTT', source_url='https://ifttt.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_t ...

# %%
csv = pd.read_csv('ua.csv')

# %%
csv.head()
# Out:
#   BambiBellina  \
# 0   TheNicoleD
# 1  CrashPad411
# 2     Durteger
# 3     imwayne_
# 4  nickjolly29
#
#   b'My Mileage Plus Explorer card doesn\xe2\x80\x99t allow me free luggage on my United flt. because it\xe2\x80\x99s a basic economy flt. (wh\xe2\x80\xa6 https://t.co/TcKmO7M8JU'
# 0  b'@UnitedAirlines This flight is in fact not o...
# 1  b'5 stops to Ohare. \xc2\xa0Nice &amp; peacefu...
# 2  b"@LeaveEUOfficial He's lucky he wasn't flying...
# 3  b'Y\xe2\x80\x99all then really played on my to...
# 4  b'Read the journey to the city of dreams "Lond...

# %%
csv
# Out:
#         BambiBellina  \
# 0         TheNicoleD
# 1        CrashPad411
# 2           Durteger
# 3           imwayne_
# 4        nickjolly29
# 5         loyndsview
# 6    GlobalTravelMgt
# 7         DenisaKera
# 8            jdmacht
# 9    10427994324a4d1
# 10   WorkHardFlyRite
# 11           subyroy
# 12        LudwigSays
# 13      RayLi_Tweets
# 14     simple_flying
# 15   GauravM57342116
# 16      Vinnypatel25
# 17        kittys5n10
# 18       AlaskaFleet
# 19         sfjen2902
# 20         virtualUA
# 21          Swaleeee
# 22       dramymcgaha
# 23        RoWardsInc
# 24       dramymcgaha
# 25          RobbRoby
# 26        HRHShelagh
# 27   michaelelaschuk
# 28    claimcompanies
# 29    LaurenMurphy19
# ..               ...
# 318     samanthakuhr
# 319     samanthakuhr
# 320      ClareKramer
# 321    Shant51072254
# 322      cityfoodbot
# 323     JoeEatsWorld
# 324  NYJusticeSeeker
# 325    ScottishField
# 326   claimcompanies
# 327        PitSch071
# 328        virtualUA
# 329        ladydigen
# 330   GlobalMarkets_
# 331     ItsDeanClark
# 332       szilviade_
# 333    cantabrodel79
# 334     arlohemphill
# 335        pickyfork
# 336        pickyfork
# 337        pickyfork
# 338     essono_verdy
# 339       szilviade_
# 340        pickyfork
# 341    RetailFashion
# 342     JoannaBunten
# 343      iTimBracken
# 344   Moonlitfirefly
# 345     JPJets_Group
# 346         BerenOcg
# 347     RALPH4MADRID
#
#     b'My Mileage Plus Explorer card doesn\xe2\x80\x99t allow me free luggage on my United flt. because it\xe2\x80\x99s a basic economy flt. (wh\xe2\x80\xa6 https://t.co/TcKmO7M8JU'
# 0    b'@UnitedAirlines This flight is in fact not o...
# 1    b'5 stops to Ohare. \xc2\xa0Nice &amp; peacefu...
# 2    b"@LeaveEUOfficial He's lucky he wasn't flying...
# 3    b'Y\xe2\x80\x99all then really played on my to...
# 4    b'Read the journey to the city of dreams "Lond...
# 5    b'5/ "Companies ranging from #Marriott to #Uni...
# 6    b'Scottish regional carrier Loganair has annou...
# 7    b'shame #unitedairlines rerouting intercontine...
# 8    b'...vacation time....Toronto \xf0\x9f\x87\xa8...
# 9    b'You know that saying, \xe2\x80\x9cDon\xe2\x8...
# 10   b'We had a great time giving \xe2\x80\x98Surpr...
# 11   b'RT @subyroy: \xe2\x80\x9cIndividuals have ri...
# 12   b'Do not fly United Airlines. Even with a Busi...
# 13   b'Hey #unitedAIRLINES , just to let you know t...
# 14   b'United Airlines Boeing 737 Diverts To Tampa ...
# 15   b'What\xe2\x80\x99s the point of 3 meat option...
# 16   b'@united both of my disabled parents are told...
# 17   b"Check out United Airlines Uniform Shirt Men'...
# 18   b'Very surprised to see United retire their A3...
# 19   b"#HappyBirthday to me!!!  Early #Birthday #pr...
# 20   b'Fly the New Spirit of United here at Virtual...
# 21   b'Sometimes I just wish I could fly. But then ...
# 22   b"Hmmm....got a reply.  Doesn't seem like they...
# 23   b'@united Not nearly appropriate or acceptable...
# 24   b'@united Would love to have a conversation wi...
# 25   b'How to know when you fly too much: you recog...
# 26   b'This could be a good delay or a really bad d...
# 27   b'Always nice to see when you land at the airp...
# 28   b'RT @hjspeer: Extremely disappointed with @un...
# 29   b'RT @hjspeer: Extremely disappointed with @un...
# ..                                                 ...
# 318  b'@united\n\n this is a bait and switch.  You ...
# 319  b'@united\n this is a bait and switch.  You of...
# 320  b'Update: This #UnitedAirlines flight has no W...
# 321  b'@UnitedAirlines just cost me more money by c...
# 322  b'RT @ScottishField: Time for an autumn break?...
# 323  b'Waiting to board our flight to SFO.\n.\n.\n....
# 324  b"#Disney to partner #StarWars #TheRiseofSkywa...
# 325  b'Time for an autumn break?\nhttps://t.co/9frD...
# 326  b'RT @PitSch071: 4 hour delay, REALLY??? My 11...
# 327  b'4 hour delay, REALLY??? My 11:30am flight fr...
# 328  b'Little quiz \xf0\x9f\x98\x8f Takeoff or land...
# 329  b'United cancels our flight so asked for a ref...
# 330  b'$UAL rejecting the $90.00 price level nicely...
# 331  b'@FAANews @Transport_gc @EASA How much more d...
# 332  b'RT @pickyfork: RT @szilviade_: RT @ScottishF...
# 333  b'RT @imriziv: Shooting a movie for @united in...
# 334  b'The amount of #SingleUsePlastic in a typical...
# 335  b'RT @szilviade_: RT @ScottishField: Time for ...
# 336  b'RT @cityfoodbot: RT @ScottishField: Time for...
# 337  b'RT @pickyfork: RT @ScottishField: Time for a...
# 338  b'RT @KateEckman: Dear @united, these are thre...
# 339  b'RT @ScottishField: Time for an autumn break?...
# 340  b'RT @ScottishField: Time for an autumn break?...
# 341  b'What does #Fashion &amp; #UnitedAirlines hav...
# 342  b'Spent two hours on a call with #unitedairlin...
# 343  b'Landing in Chicago en route to Los Angeles. ...
# 344  b'I got my wings today!! Thank you Pilot Brian...
# 345  b'An old video of a United Airlines DC 10 goin...
# 346  b'#unitedairlines UA6177 dripping water in sea...
# 347  b'RT @TravelPulse: On Sunday, a @united Airlin...
#
# [348 rows x 2 columns]

# %%
csv['BambiBellina'].value_counts()[:]
# Out:
# claimcompanies     13
# TravelPulse         6
# ryan_m2019          5
# pickyfork           4
# JasmineMcAlist2     4
# trmbn65             4
# jAdor3_ReNee        3
# JPJets_Group        3
# ChartersBus         3
# JcOrdorica          3
# CharlestonSF        3
# Brandon33045499     3
# RoWardsInc          3
# David_L_London      3
# SuperbSpeakers      2
# CTaylorBirder       2
# virtualUA           2
# RobbRoby            2
# dramymcgaha         2
# TykesAeroBlog       2
# csfernandez1977     2
# IamSusanRoberts     2
# FlightModeblog      2
# tuningelement       2
# JoeEatsWorld        2
# mkeway4noddy        2
# UnitedRachel        2
# JetsonLes           2
# GlobalTravelMgt     2
# slprosper           2
#                    ..
# annmariastat        1
# byronmcwilliams     1
# ErikGlitman         1
# GH_obsession1       1
# vilade_john         1
# Lucy59jarvis        1
# commonsence1822     1
# kisrani             1
# MeH_not_meh         1
# REZBOMB             1
# WorkHardFlyRite     1
# Jennifer_Jones      1
# NYJusticeSeeker     1
# zachfowlermusic     1
# Remedine            1
# MsDeeZok            1
# RenaMason88         1
# arlohemphill        1
# agolod13            1
# paulamhall          1
# MileageRunner       1
# SanitaMusselaya     1
# loyndsview          1
# sugarclint          1
# essono_verdy        1
# AndreMoten          1
# AlisaVoris          1
# KeikoA730           1
# coryokeefe          1
# FlightDevRBX        1
# Name: BambiBellina, Length: 280, dtype: int64
